# %% [markdown]
# # **NYC Taxi Data Analysis - Yellow Taxis**
#
# Exploratory analysis on NYC Yellow Taxis looking into customer segmentation and factors that may impact tipping behaviors across the 5 boroughs
#
# ---

# %% [markdown]
# ### **Imports & Setup**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../scripts') # imports custom scripts from the scripts directory
from data_utils import remove_outliers

# setting display options for pandas
pd.set_option('display.max_columns', None) # displays all columns in the dataframe
pd.set_option('display.max_rows', 100) # sets the max number of rows to 100

# %% [markdown]
# ### **Loading Data**

# %%
# look up tables
zone = pd.read_csv('../data/taxi_zone_lookup.csv') 
vendor = pd.read_csv('../data/taxi_vendor_lookup.csv')
payment = pd.read_csv('../data/payment_lookup.csv')
ratecode = pd.read_csv('../data/ratecode_lookup.csv')

# yellow taxi data
df = pd.read_parquet('../data/yellow_tripdata_2025-05.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4591845 entries, 0 to 4591844
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
# dtypes: datetime64[us](2), float64(13), int32(3), int64(1), object(1)
# memory usage: 648.1+ MB

# %%
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  4.591845e+06                     4591845                     4591845
# mean   1.875653e+00  2025-05-16 07:15:25.300312  2025-05-16 07:33:20.003034
# min    1.000000e+00         2009-01-01 00:20:39         2009-01-01 00:20:49
# 25%    2.000000e+00         2025-05-08 18:23:12         2025-05-08 18:42:50
# 50%    2.000000e+00         2025-05-16 00:49:45         2025-05-16 01:05:55
# 75%    2.000000e+00         2025-05-23 13:28:04         2025-05-23 13:47:48
# max    7.000000e+00         2025-06-01 00:04:31         2025-06-04 11:17:10
# std    7.239395e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     3.395669e+06   4.591845e+06  3.395669e+06  4.591845e+06
# mean      1.295270e+00   7.653422e+00  2.432585e+00  1.611871e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# 25%       1.000000e+00   1.060000e+00  1.000000e+00  1.140000e+02
# 50%       1.000000e+00   1.890000e+00  1.000000e+00  1.610000e+02
# 75%       1.000000e+00   3.770000e+00  1.000000e+00  2.330000e+02
# max       9.000000e+00   2.631040e+05  9.900000e+01  2.650000e+02
# std       7.252927e-01   6.533947e+02  1.133495e+01  6.655046e+01
#
#        DOLocationID  payment_type   fare_amount         extra       mta_tax  \
# count  4.591845e+06  4.591845e+06  4.591845e+06  4.591845e+06  4.591845e+06
# mean   1.611876e+02  9.123720e-01  1.835794e+01  1.164838e+00  4.774078e-01
# min    1.000000e+00  0.000000e+00 -9.980000e+02 -1.739000e+01 -5.000000e-01
# 25%    1.070000e+02  0.000000e+00  8.600000e+00  0.000000e+00  5.000000e-01
# 50%    1.620000e+02  1.000000e+00  1.415000e+01  0.000000e+00  5.000000e-01
# 75%    2.330000e+02  1.000000e+00  2.300000e+01  2.500000e+00  5.000000e-01
# max    2.650000e+02  4.000000e+00  1.583600e+03  1.336000e+02  2.214000e+01
# std    7.058759e+01  7.590985e-01  1.982062e+01  1.845559e+00  1.380384e-01
#
#          tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# count  4.591845e+06  4.591845e+06           4.591845e+06  4.591845e+06
# mean   2.858122e+00  5.114760e-01           9.563765e-01  2.688033e+01
# min   -9.044000e+01 -1.481700e+02          -1.000000e+00 -1.147170e+03
# 25%    0.000000e+00  0.000000e+00           1.000000e+00  1.554000e+01
# 50%    2.000000e+00  0.000000e+00           1.000000e+00  2.142000e+01
# 75%    4.000000e+00  0.000000e+00           1.000000e+00  3.098000e+01
# max    4.432100e+02  1.481700e+02           1.000000e+00  1.614290e+03
# std    4.043892e+00  2.144886e+00           2.750487e-01  2.419524e+01
#
#        congestion_surcharge   Airport_fee  cbd_congestion_fee
# count          3.395669e+06  3.395669e+06        4.591845e+06
# mean           2.197677e+00  1.531993e-01        5.278734e-01
# min           -2.500000e+00 -1.750000e+00       -7.500000e-01
# 25%            2.500000e+00  0.000000e+00        0.000000e+00
# 50%            2.500000e+00  0.000000e+00        7.500000e-01
# 75%            2.500000e+00  0.000000e+00        7.500000e-01
# max            2.500000e+00  6.750000e+00        1.250000e+00
# std            9.446371e-01  5.431268e-01        3.607600e-01

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-05-01 00:07:06   2025-05-01 00:24:15              1.0
# 1         2  2025-05-01 00:07:44   2025-05-01 00:14:27              1.0
# 2         2  2025-05-01 00:15:56   2025-05-01 00:23:53              1.0
# 3         2  2025-05-01 00:00:09   2025-05-01 00:25:29              1.0
# 4         2  2025-05-01 00:45:07   2025-05-01 00:52:45              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.70         1.0                  N           140           202
# 1           1.03         1.0                  N           234           161
# 2           1.57         1.0                  N           161           234
# 3           9.48         1.0                  N           138            90
# 4           1.80         1.0                  N            90           231
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         18.4   4.25      0.5        4.85          0.00
# 1             1          8.6   1.00      0.5        4.30          0.00
# 2             2         10.0   1.00      0.5        0.00          0.00
# 3             1         40.8   6.00      0.5       11.70          6.94
# 4             1         10.0   1.00      0.5        1.50          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         29.00                   2.5         0.00
# 1                    1.0         18.65                   2.5         0.00
# 2                    1.0         15.75                   2.5         0.00
# 3                    1.0         71.94                   2.5         1.75
# 4                    1.0         17.25                   2.5         0.00
#
#    cbd_congestion_fee
# 0                0.75
# 1                0.75
# 2                0.75
# 3                0.75
# 4                0.75

# %% [markdown]
# ---
# ### **Data Assumptions**
# * Each row represents a single trip record
# * No explicit primary key column
# * Each row's uniqueness could be composed of a combination of columns (pickup, dropoff, vendor)
#
# *Note: for this exploratory analysis, a primary key is not critical, as much of the analysis is focused on aggregation patterns rather than uniquely identifying rows*
# > If necessary, could implement 'ride_id' as a primary key using row index

# %% [markdown]
# ---
# ### **Data Cleaning**

# %%
# shows the number of missing values per column
df.isna().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1196176
# trip_distance                  0
# RatecodeID               1196176
# store_and_fwd_flag       1196176
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     1196176
# Airport_fee              1196176
# cbd_congestion_fee             0
# dtype: int64

# %%
# checking to see the unique values in the passenger_count column 
df['passenger_count'].unique()
# Out:
# array([ 1.,  0.,  2.,  3.,  4.,  5.,  6.,  9.,  8., nan])

# %%
# it's odd that there are so many 0's for passenger_count, doesn't make sense, investigate further
df[df['passenger_count'] == 0]

# doesn't seem like there was an actual reason for it, will replace 0s with nulls for now
# also replace np.nan with NA to standardize
df['passenger_count'] = df['passenger_count'].replace({0: pd.NA, np.nan: pd.NA})

# %%
# dropping store_and_fwd_flag because it's not relevant for this specific analysis
df.drop(columns=['store_and_fwd_flag'], inplace=True)

# %%
df.isna().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1220143
# trip_distance                  0
# RatecodeID               1196176
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     1196176
# Airport_fee              1196176
# cbd_congestion_fee             0
# dtype: int64

# %%
df['RatecodeID'].unique()
# Out:
# array([ 1.,  2., 99.,  5.,  4.,  3.,  6., nan])

# %%
# there are nulls for ratecodeid, according to the source dict 99 stands for null/unknown
df[df['RatecodeID'] == 99]

# replace nulls with 99
df['RatecodeID'] = df['RatecodeID'].replace(np.nan, 99)

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# checking lookup tables individually
zone.head()
payment.head()
ratecode.head() 
vendor.head()
# Out:
#    VendorID                        vendor_name  Unnamed: 2
# 0         1  Creative Mobile Technologies, LLC         NaN
# 1         2                 Curb Mobility, LLC         NaN
# 2         6              Myle Technologies Inc         NaN
# 3         7                              Helix         NaN

# %%
# vendor has 2 unnamed columns, let's filter those out
vendor = vendor.loc[:, ~vendor.columns.str.contains('^Unnamed')] # ~ removes columns that start with 'Unnamed'
vendor.head()
# Out:
#    VendorID                        vendor_name
# 0         1  Creative Mobile Technologies, LLC
# 1         2                 Curb Mobility, LLC
# 2         6              Myle Technologies Inc
# 3         7                              Helix

# %% [markdown]
# ---
# ### **Exploratory**: The 5 boroughs of NYC
#
# __A few notes:__
#
# 1. Borough DataFrames:
#     > DataFrames named after a borough (e.g., `manhattan`, `queens`) contain only rides where both pickup and dropoff are within that borough.
# 2. '_overall' DataFrames:
#     > DataFrames with '_overall' (e.g., `manhattan_overall`) include any ride where either the pickup or dropoff is in that borough.
# 3. '_cleaned' DataFrames:
#     > DataFrames with '_cleaned' (e.g., `queens_cleaned`) have extreme outliers in trip duration and distance removed. These are used for analyses that are sensitive to outliers (like distribution or clustering analysis).
# 1. Uncleaned DataFrames for Tipping Analysis:
#     > For tipping behavior analysis, the original (uncleaned) DataFrames are used. This is because, even if some values are likely input errors, the rides themselves probably occurred and may still reflect real-world tipping patterns.
# 2. Why Use Different DataFrames:
#     > Different questions require different scopes: some analyses need clean data to avoid skewed results, while others (like tipping) benefit from including all rides, even those with data entry issues.

# %%
# merging lookup tables with the taxi data
# using left joins because we want to retain all records from the taxi data

# saving location information based off PULocationID & DOLocationID
merged = df.merge(zone, how='left', left_on='PULocationID', right_on='LocationID').rename(columns={'Borough': 'PU_Borough', 'Zone': 'PU_Zone', 'service_zone': 'PU_service_zone'})
merged = merged.merge(zone, how='left', left_on='DOLocationID', right_on='LocationID').rename(columns={'Borough': 'DO_Borough', 'Zone': 'DO_Zone', 'service_zone': 'DO_service_zone'})

# dropping the LocationID columns as they are no longer needed
merged = merged.drop(columns=['LocationID_x', 'LocationID_y'])

# merging the rest of the lookups
merged = merged.merge(vendor, how='left', on='VendorID').merge(payment, how='left', on='payment_type').merge(ratecode, how='left', on='RatecodeID')

# create a column with the difference between pickup and dropoff datetime as 'duration_mins'
merged['duration_mins'] = (merged['tpep_dropoff_datetime'] - merged['tpep_pickup_datetime']).dt.total_seconds() / 60 # duration in minutes

merged.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime passenger_count  \
# 0         1  2025-05-01 00:07:06   2025-05-01 00:24:15             1.0
# 1         2  2025-05-01 00:07:44   2025-05-01 00:14:27             1.0
# 2         2  2025-05-01 00:15:56   2025-05-01 00:23:53             1.0
# 3         2  2025-05-01 00:00:09   2025-05-01 00:25:29             1.0
# 4         2  2025-05-01 00:45:07   2025-05-01 00:52:45             1.0
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           3.70         1.0           140           202             1
# 1           1.03         1.0           234           161             1
# 2           1.57         1.0           161           234             2
# 3           9.48         1.0           138            90             1
# 4           1.80         1.0            90           231             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         18.4   4.25      0.5        4.85          0.00
# 1          8.6   1.00      0.5        4.30          0.00
# 2         10.0   1.00      0.5        0.00          0.00
# 3         40.8   6.00      0.5       11.70          6.94
# 4         10.0   1.00      0.5        1.50          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         29.00                   2.5         0.00
# 1                    1.0         18.65                   2.5         0.00
# 2                    1.0         15.75                   2.5         0.00
# 3                    1.0         71.94                   2.5         1.75
# 4                    1.0         17.25                   2.5         0.00
#
#    cbd_congestion_fee PU_Borough            PU_Zone PU_service_zone  \
# 0                0.75  Manhattan    Lenox Hill East     Yellow Zone
# 1                0.75  Manhattan           Union Sq     Yellow Zone
# 2                0.75  Manhattan     Midtown Center     Yellow Zone
# 3                0.75     Queens  LaGuardia Airport        Airports
# 4                0.75  Manhattan           Flatiron     Yellow Zone
#
#   DO_Borough               DO_Zone DO_service_zone  \
# 0  Manhattan      Roosevelt Island       Boro Zone
# 1  Manhattan        Midtown Center     Yellow Zone
# 2  Manhattan              Union Sq     Yellow Zone
# 3  Manhattan              Flatiron     Yellow Zone
# 4  Manhattan  TriBeCa/Civic Center     Yellow Zone
#
#                          vendor_name payment_method       Rate  duration_mins
# 0  Creative Mobile Technologies, LLC    Credit card  Standard       17.150000
# 1                 Curb Mobility, LLC    Credit card  Standard        6.716667
# 2                 Curb Mobility, LLC           Cash  Standard        7.950000
# 3                 Curb Mobility, LLC    Credit card  Standard       25.333333
# 4                 Curb Mobility, LLC    Credit card  Standard        7.633333

# %%
merged.isna().sum() #after merging, there are some nulls in the lookup columns, which is expected since not all records will have a corresponding entry in the lookup tables
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1220143
# trip_distance                  0
# RatecodeID                     0
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     1196176
# Airport_fee              1196176
# cbd_congestion_fee             0
# PU_Borough                  2091
# PU_Zone                     7596
# PU_service_zone             9687
# DO_Borough                 20490
# DO_Zone                     9800
# DO_service_zone            30290
# vendor_name                    0
# payment_method                 0
# Rate                           0
# duration_mins                  0
# dtype: int64

# %%
# checking unique values in the merged columns
merged['PU_Zone'].unique() 
merged['DO_Zone'].unique()
merged['PU_Borough'].unique() 
merged['DO_Borough'].unique() 

# there are 'Unknown' and 'NaN' values in PU_Borough & DO_Borough, replace na with 'Unknown' for consistency
merged['PU_Borough'].replace(np.nan, 'Unknown', inplace=True)
merged['DO_Borough'].replace(np.nan, 'Unknown', inplace=True)

# %% [markdown]
# #### **Understanding the Data (Geographic & Trip Characteristics)**
# >How often people request rides & where/when they request the most?
# * Focusing on datetime & location to perform frequency based aggregation

# %%
ride_combination = merged.groupby(['PU_Borough', 'DO_Borough']).size().reset_index(name='count')  # count occurrences of rides requested from PU_Borough and DO_Borough
ride_combination.sort_values(by='count',ascending=False, inplace=True)  # sort by count in descending order
ride_combination.head() # by a good chunk, the most frequent combination is from Manhattan to Manhattan
# Out:
#    PU_Borough DO_Borough    count
# 23  Manhattan  Manhattan  3657462
# 30     Queens  Manhattan   225823
# 31     Queens     Queens   136701
# 24  Manhattan     Queens   114579
# 8    Brooklyn   Brooklyn   104316

# %% [markdown]
# *As shown above:*
# > The results shows Manhattan having the most ride frequency, let's investigate Manhattan a bit further:
#   * Could there be a trend since most rides are within Manhattan?
#     * Maybe yellow taxis are commonly used for short trips strictly within Manhattan, which could be why we see a high number of rides from __Manhattan to Manhattan__
#     * Let's take a closer look at the datetime & trip distance to confirm the durations of these rides

# %%
# strictly Manhattan (PU_Borough and DO_Borough both equal 'Manhattan')
manhattan = merged[(merged['PU_Borough'] == 'Manhattan') & (merged['DO_Borough'] == 'Manhattan')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
manhattan_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
manhattan = manhattan[manhattan_datetime_cols + [c for c in manhattan.columns if c not in manhattan_datetime_cols]]
manhattan.head()
# Out:
#           PU_datetime         DO_datetime  duration_mins  trip_distance  \
# 0 2025-05-01 00:07:06 2025-05-01 00:24:15      17.150000           3.70
# 1 2025-05-01 00:07:44 2025-05-01 00:14:27       6.716667           1.03
# 2 2025-05-01 00:15:56 2025-05-01 00:23:53       7.950000           1.57
# 4 2025-05-01 00:45:07 2025-05-01 00:52:45       7.633333           1.80
# 6 2025-05-01 00:18:14 2025-05-01 00:27:38       9.400000           1.50
#
#   passenger_count          PU_Zone PU_service_zone               DO_Zone  \
# 0             1.0  Lenox Hill East     Yellow Zone      Roosevelt Island
# 1             1.0         Union Sq     Yellow Zone        Midtown Center
# 2             1.0   Midtown Center     Yellow Zone              Union Sq
# 4             1.0         Flatiron     Yellow Zone  TriBeCa/Civic Center
# 6            <NA>  Lenox Hill East     Yellow Zone        Yorkville West
#
#   DO_service_zone  VendorID  RatecodeID  PULocationID  DOLocationID  \
# 0       Boro Zone         1         1.0           140           202
# 1     Yellow Zone         2         1.0           234           161
# 2     Yellow Zone         2         1.0           161           234
# 4     Yellow Zone         2         1.0            90           231
# 6     Yellow Zone         1         1.0           140           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         18.4   4.25      0.5        4.85           0.0
# 1             1          8.6   1.00      0.5        4.30           0.0
# 2             2         10.0   1.00      0.5        0.00           0.0
# 4             1         10.0   1.00      0.5        1.50           0.0
# 6             1         11.4   3.50      0.5        4.05           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         29.00                   2.5          0.0
# 1                    1.0         18.65                   2.5          0.0
# 2                    1.0         15.75                   2.5          0.0
# 4                    1.0         17.25                   2.5          0.0
# 6                    1.0         20.45                   2.5          0.0
#
#    cbd_congestion_fee PU_Borough DO_Borough  \
# 0                0.75  Manhattan  Manhattan
# 1                0.75  Manhattan  Manhattan
# 2                0.75  Manhattan  Manhattan
# 4                0.75  Manhattan  Manhattan
# 6                0.00  Manhattan  Manhattan
#
#                          vendor_name payment_method       Rate
# 0  Creative Mobile Technologies, LLC    Credit card  Standard
# 1                 Curb Mobility, LLC    Credit card  Standard
# 2                 Curb Mobility, LLC           Cash  Standard
# 4                 Curb Mobility, LLC    Credit card  Standard
# 6  Creative Mobile Technologies, LLC    Credit card  Standard

# %%
# what is the % of manhattan to manhattan rides that have short durations or trip distances?
# first, lets take a look at the distribution of trip durations and distances 
manhattan[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count   3.657462e+06   3.657462e+06
# mean    1.406164e+01   4.643753e+00
# std     2.414157e+01   5.236386e+02
# min    -2.183333e+00   0.000000e+00
# 25%     7.550000e+00   9.500000e-01
# 50%     1.208333e+01   1.580000e+00
# 75%     1.816667e+01   2.560000e+00
# max     7.664717e+03   2.631040e+05

# %%
# let's filter out negative values, likely input error --> using a cleaned version of manhattan
# doesn't seem to have extreme outliers
manhattan_cleaned = manhattan[manhattan['duration_mins'] >= 0]
manhattan_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count   3.657438e+06   3.657438e+06
# mean    1.406173e+01   4.643766e+00
# std     2.414163e+01   5.236403e+02
# min     0.000000e+00   0.000000e+00
# 25%     7.550000e+00   9.500000e-01
# 50%     1.208333e+01   1.580000e+00
# 75%     1.816667e+01   2.560000e+00
# max     7.664717e+03   2.631040e+05

# %%
merged[['trip_distance', 'duration_mins']].describe()
# Out:
#        trip_distance  duration_mins
# count   4.591845e+06   4.591845e+06
# mean    7.653422e+00   1.791171e+01
# std     6.533947e+02   2.799913e+01
# min     0.000000e+00  -6.810833e+02
# 25%     1.060000e+00   8.366667e+00
# 50%     1.890000e+00   1.391667e+01
# 75%     3.770000e+00   2.216667e+01
# max     2.631040e+05   7.664717e+03

# %%
# let's also clean the merged DataFrame to remove negative values
merged_cleaned = merged[merged['duration_mins'] >= 0]
# we can use values <= the 25th percentile of the overall df to define short rides by durations or distances
duration_25_all = merged_cleaned['duration_mins'].quantile(0.25)
distance_25_all = merged_cleaned['trip_distance'].quantile(0.25)

# defining short rides in Manhattan
m_short_rides = manhattan_cleaned[(manhattan_cleaned['duration_mins'] <= duration_25_all) | (manhattan_cleaned['trip_distance'] <= distance_25_all)] # all rides with short durations or distances
m_short_rides_count = m_short_rides.shape[0]
total_rides_count = manhattan_cleaned.shape[0]
m_short_rides_percentage = (m_short_rides_count / total_rides_count) * 100
print(f"% of short rides in Manhattan (by duration or distance): {m_short_rides_percentage:.2f}%")
# Out:
# % of short rides in Manhattan (by duration or distance): 38.83%

# %% [markdown]
# >It doesn't necessarily seem like yellow taxis are used for short trips strictly in Manhattan
# * Let's look from a broader perspective and display zones pairs where rides are frequently being called from and to

# %%
# rides involving Manhattan (either PU_Borough or DO_Borough equal 'Manhattan')
manhattan_overall = merged[(merged['PU_Borough'] == 'Manhattan') | (merged['DO_Borough'] == 'Manhattan')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})
manhattan_overall.groupby(['PU_Zone', 'DO_Zone']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(10)  # top 10 most frequent ride combinations involving Manhattan
# Out:
#                      PU_Zone                DO_Zone  count
# 18782  Upper East Side South  Upper East Side North  29651
# 18547  Upper East Side North  Upper East Side South  25399
# 18783  Upper East Side South  Upper East Side South  20890
# 18546  Upper East Side North  Upper East Side North  19259
# 12306         Midtown Center  Upper East Side South  13813
# 18711  Upper East Side South         Midtown Center  12992
# 12305         Midtown Center  Upper East Side North  10849
# 10345    Lincoln Square East  Upper West Side South  10146
# 18712  Upper East Side South           Midtown East   9970
# 18479  Upper East Side North         Midtown Center   9769

# %% [markdown]
# >Could be useful to look into Same-Zone Rides in Manhattan vs. Manhattan-Involved Rides

# %%
# Checking the amount of rides within the same zone for strictly Manhattan 
m_same_zone_count = manhattan[manhattan['PU_Zone'] == manhattan['DO_Zone']].shape[0]
m_same_zone_percentage = (m_same_zone_count/manhattan.shape[0])*100  # percentage of rides within the same zone in Manhattan
print(f"% of same zone rides in Manhattan: {m_same_zone_percentage:.2f}%")
# Out:
# % of same zone rides in Manhattan: 4.70%

# %% [markdown]
# >It's a low percentage:
#   * Maybe there are less local taxi rides because the borough is more walkable?
#     * Considering the numbers are on the lower end for duration and distance
#     * Could indicate most taxi rides are cross-neighborhood or intra-borough
#     * Will compare with other boroughs to see if Manhattan is unique in this behavior

# %%
# Checking the amount of rides within the same zone for all Manhattan-involved rides
m_same_zone_percentage = (m_same_zone_count/manhattan_overall.shape[0])*100  # percentage of rides within the same zone in Manhattan
print(f"% of same zone rides involving Manhattan: {m_same_zone_percentage:.2f}%")
# Out:
# % of same zone rides in Manhattan: 4.09%

# %% [markdown]
# > The percentage is low for both, and even lower when considering all Manhattan-involved rides
# * This demonstrates that most yellow taxi rides in Manhattan are not hyper-local, but instead cross zones or neighborhoods.
# * This pattern supports the idea that Manhattan's walkability reduces the need for taxis for very short, local trips.

# %% [markdown]
# >Analyzing the rest of the boroughs: Queens

# %%
# strictly Queens (PU_Borough and DO_Borough both equal 'Queens')
queens = merged[(merged['PU_Borough'] == 'Queens') & (merged['DO_Borough'] == 'Queens')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
queens_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
queens = queens[queens_datetime_cols + [c for c in queens.columns if c not in queens_datetime_cols]]
queens.head()
# Out:
#             PU_datetime         DO_datetime  duration_mins  trip_distance  \
# 5   2025-05-01 00:09:24 2025-05-01 00:22:04      12.666667           5.11
# 54  2025-05-01 00:39:32 2025-05-01 01:13:48      34.266667          16.51
# 126 2025-05-01 00:11:11 2025-05-01 00:24:54      13.716667           4.53
# 148 2025-05-01 00:29:36 2025-05-01 01:06:47      37.183333           9.18
# 172 2025-05-01 00:13:08 2025-05-01 00:30:13      17.083333           7.20
#
#     passenger_count            PU_Zone PU_service_zone        DO_Zone  \
# 5               1.0  LaGuardia Airport        Airports      Sunnyside
# 54              1.0        JFK Airport        Airports    JFK Airport
# 126             2.0        JFK Airport        Airports  Richmond Hill
# 148             2.0        JFK Airport        Airports         Hollis
# 172             1.0  LaGuardia Airport        Airports    Kew Gardens
#
#     DO_service_zone  VendorID  RatecodeID  PULocationID  DOLocationID  \
# 5         Boro Zone         2         1.0           138           226
# 54         Airports         2         1.0           132           132
# 126       Boro Zone         2         1.0           132           197
# 148       Boro Zone         2         1.0           132           122
# 172       Boro Zone         1         1.0           138           134
#
#      payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 5               1         22.6   6.00      0.5        6.02           0.0
# 54              1         66.0   1.00      0.5       17.12           0.0
# 126             1         20.5   1.00      0.5        6.90           0.0
# 148             2         43.6   1.00      0.5        0.00           0.0
# 172             2         29.6   7.75      0.5        0.00           0.0
#
#      improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 5                      1.0         37.87                   0.0         1.75
# 54                     1.0         85.62                   0.0         0.00
# 126                    1.0         31.65                   0.0         1.75
# 148                    1.0         47.85                   0.0         1.75
# 172                    1.0         38.85                   0.0         1.75
#
#      cbd_congestion_fee PU_Borough DO_Borough  \
# 5                   0.0     Queens     Queens
# 54                  0.0     Queens     Queens
# 126                 0.0     Queens     Queens
# 148                 0.0     Queens     Queens
# 172                 0.0     Queens     Queens
#
#                            vendor_name payment_method       Rate
# 5                   Curb Mobility, LLC    Credit card  Standard
# 54                  Curb Mobility, LLC    Credit card  Standard
# 126                 Curb Mobility, LLC    Credit card  Standard
# 148                 Curb Mobility, LLC           Cash  Standard
# 172  Creative Mobile Technologies, LLC           Cash  Standard

# %% [markdown]
# > It seems like there's a lot of service for airports (LaGuardia & JFK) strictly within Queens
# * Worth noting that both airports are located in Queens, could explain the high volume of airport type services

# %%
# checking the amount of rides in each service_zone
q_PU_service_zones = queens['PU_service_zone'].value_counts() 
q_DO_service_zones = queens['DO_service_zone'].value_counts()

pd.concat([q_PU_service_zones, q_DO_service_zones], axis=1) # side-by-side counts of PU and DO service zones for Queens
# Out:
#            count   count
# Boro Zone  70585  114926
# Airports   66116   21775

# %% [markdown]
# > Looks like there's more airport services at pickup compared to dropoff

# %%
# rides involving Queens (either PU_Borough or DO_Borough equal 'Queens')
queens_overall = merged[(merged['PU_Borough'] == 'Queens') | (merged['DO_Borough'] == 'Queens')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# the percentage of rides that are airport-related
q_airport_rides = queens_overall[queens_overall['PU_service_zone'].str.contains('Airport') | queens_overall['DO_service_zone'].str.contains('Airport')].shape[0]
q_airport_percentage = (q_airport_rides / queens_overall.shape[0]) * 100
print(f"% of airport-related rides in queens: {q_airport_percentage:.2f}%")
# Out:
# % of airport-related rides in queens: 67.23%

# %%
# Let's take a look at how many of manhattan rides are airport-related at pickup and dropoff
m_airport_rides = manhattan_overall[manhattan_overall['PU_service_zone'].str.contains('Airport') | manhattan_overall['DO_service_zone'].str.contains('Airport')].shape[0]
m_airport_percentage = (m_airport_rides / manhattan_overall.shape[0]) * 100
print(f"% of airport-related rides in manhattan: {m_airport_percentage:.2f}%")
# Out:
# % of airport-related rides in manhattan: 6.20%

# %% [markdown]
# * In total, over half the rides involving queens are airport-related
# * Could be that queens uses taxi services for lesser casual means
#   * Longer trips

# %%
# let's filter out the extreme outliers in both columns
queens_cleaned = remove_outliers(queens)
queens_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count  120305.000000  120305.000000
# mean       18.218662       5.671123
# std        11.372003       3.965334
# min         0.100000       0.010000
# 25%        10.383333       2.430000
# 50%        16.233333       4.900000
# 75%        23.983333       8.480000
# max        61.050000      16.570000

# %% [markdown]
# *As shown above:*
# * The duration is much higher than that of Manhattan, which could be due to the fact that Queens is less densely populated and has longer distances between locations
# * Which could mean that Queens uses taxi services for longer trips, possibly for airport-related services or other longer-distance travel needs
# * Meaning queens is less walkable and has longer distances between locations

# %% [markdown]
# >Analyzing the rest of the boroughs: Brooklyn

# %%
# strictly Brooklyn (PU_Borough and DO_Borough both equal 'Brooklyn')
brooklyn = merged[(merged['PU_Borough'] == 'Brooklyn') & (merged['DO_Borough'] == 'Brooklyn')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# rides involving Brooklyn (either PU_Borough or DO_Borough equal 'Brooklyn')
brooklyn_overall = merged[(merged['PU_Borough'] == 'Brooklyn') | (merged['DO_Borough'] == 'Brooklyn')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
brooklyn_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
brooklyn = brooklyn[brooklyn_datetime_cols + [c for c in brooklyn.columns if c not in brooklyn_datetime_cols]]
brooklyn.head()
# Out:
#             PU_datetime         DO_datetime  duration_mins  trip_distance  \
# 266 2025-05-01 00:00:07 2025-05-01 00:22:57      22.833333           3.91
# 313 2025-05-01 00:28:24 2025-05-01 00:34:01       5.616667           1.00
# 484 2025-05-01 00:50:08 2025-05-01 00:56:34       6.433333           1.03
# 567 2025-05-01 00:12:59 2025-05-01 00:26:24      13.416667           2.80
# 760 2025-05-01 00:54:25 2025-05-01 01:10:29      16.066667           4.51
#
#     passenger_count                    PU_Zone PU_service_zone  \
# 266             1.0                Boerum Hill       Boro Zone
# 313             1.0  Williamsburg (South Side)       Boro Zone
# 484             1.0  Williamsburg (North Side)       Boro Zone
# 567             1.0              Prospect Park       Boro Zone
# 760             1.0  Williamsburg (North Side)       Boro Zone
#
#                        DO_Zone DO_service_zone  VendorID  RatecodeID  \
# 266           Sunset Park West       Boro Zone         2         1.0
# 313  Williamsburg (South Side)       Boro Zone         1         1.0
# 484          East Williamsburg       Boro Zone         2         1.0
# 567       Flatbush/Ditmas Park       Boro Zone         2         1.0
# 760            Carroll Gardens       Boro Zone         2         1.0
#
#      PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 266            25           228             2         24.0    1.0      0.5
# 313           256           256             1          7.2    1.0      0.5
# 484           255            80             1          7.9    1.0      0.5
# 567           190            89             1         15.6    1.0      0.5
# 760           255            40             1         21.9    1.0      0.5
#
#      tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 266        0.00           0.0                    1.0         26.50
# 313        4.00           0.0                    1.0         13.70
# 484        3.12           0.0                    1.0         13.52
# 567        3.62           0.0                    1.0         21.72
# 760        4.88           0.0                    1.0         29.28
#
#      congestion_surcharge  Airport_fee  cbd_congestion_fee PU_Borough  \
# 266                   0.0          0.0                 0.0   Brooklyn
# 313                   0.0          0.0                 0.0   Brooklyn
# 484                   0.0          0.0                 0.0   Brooklyn
# 567                   0.0          0.0                 0.0   Brooklyn
# 760                   0.0          0.0                 0.0   Brooklyn
#
#     DO_Borough                        vendor_name payment_method       Rate
# 266   Brooklyn                 Curb Mobility, LLC           Cash  Standard
# 313   Brooklyn  Creative Mobile Technologies, LLC    Credit card  Standard
# 484   Brooklyn                 Curb Mobility, LLC    Credit card  Standard
# 567   Brooklyn                 Curb Mobility, LLC    Credit card  Standard
# 760   Brooklyn                 Curb Mobility, LLC    Credit card  Standard

# %%
brooklyn[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count  104316.000000  104316.000000
# mean       20.421525      18.990859
# std        14.607040    1126.482350
# min        -9.066667       0.000000
# 25%        11.816667       1.530000
# 50%        18.100000       2.830000
# 75%        26.170833       4.400000
# max      1419.316667  125465.400000

# %%
# let's filter out the extreme outliers in both columns
brooklyn_cleaned = remove_outliers(brooklyn)
brooklyn_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count   94404.000000   94404.000000
# mean       20.098065       3.424336
# std        10.882119       2.247111
# min         2.316667       0.010000
# 25%        12.150000       1.800000
# 50%        18.133333       3.000000
# 75%        25.833333       4.440000
# max        65.250000      13.200000

# %% [markdown]
# > It seems within brooklyn, the duration and distance is longer than manhattan, but slightly similar to queens
# * What are the most common pickup and dropoff zones
# * Dig deeper into short vs. long rides

# %%
# checking the paired zones in Brooklyn
brooklyn.groupby(['PU_Zone','DO_Zone']).size().reset_index(name='counts').sort_values(by='counts', ascending=False).head(10)  # top 10 most frequent pickup service zones in Brooklyn
# Out:
#                         PU_Zone                    DO_Zone  counts
# 1570              East New York              East New York     655
# 1098        Crown Heights North        Crown Heights North     434
# 2652                 Park Slope                 Park Slope     403
# 747                    Canarsie                   Canarsie     400
# 2120                 Greenpoint                 Greenpoint     349
# 3272  Williamsburg (North Side)                 Greenpoint     338
# 45                    Bay Ridge                  Bay Ridge     326
# 3248  Williamsburg (North Side)             Bushwick South     323
# 1808       Flatbush/Ditmas Park       Flatbush/Ditmas Park     277
# 3293  Williamsburg (North Side)  Williamsburg (North Side)     276

# %%
# numbers seem small
# checking the amount of rides within the same zone for strictly Brooklyn 
b_same_zone_count = brooklyn[brooklyn['PU_Zone'] == brooklyn['DO_Zone']].shape[0]
b_same_zone_percentage = (b_same_zone_count/brooklyn.shape[0])*100  # percentage of rides within the same zone in Brooklyn
print(f"% of same zone rides in Brooklyn: {b_same_zone_percentage:.2f}%")
# Out:
# % of same zone rides in Brooklyn: 7.45%

# %%
# checking the amount of rides within the same zone for all Brooklyn-involved rides
b_same_zone_percentage = (b_same_zone_count/brooklyn_overall.shape[0])*100  # percentage of rides within the same zone in Brooklyn
print(f"% of same zone rides in Brooklyn: {b_same_zone_percentage:.2f}%")
# Out:
# % of same zone rides in Brooklyn: 2.25%

# %% [markdown]
# > Could be that Brooklyn is a borough that's considered "walkable" due to the low %
# * But if that's the case, why are the numbers so different than Manhattan?
#   * Most of the rides may be for intra-borough trips, I'd assume brooklyn's neighborhoods would be further apart due to the larger numbers for brooklyn

# %%
# let's compare short rides vs. long rides in Brooklyn
# first, we can use the same 25th percentile values for duration and distance as we did for Manhattan

# defining short rides in Brooklyn
b_short_rides = brooklyn_cleaned[(brooklyn_cleaned['duration_mins'] <= duration_25_all) | (brooklyn_cleaned['trip_distance'] <= distance_25_all)] # all rides with short durations or distances
b_short_rides_count = b_short_rides.shape[0]
total_brooklyn_rides = brooklyn_cleaned.shape[0]
b_short_rides_percentage = (b_short_rides_count / total_brooklyn_rides) * 100
print(f"% of short rides in Brooklyn (by duration or distance): {b_short_rides_percentage:.2f}%")

# defining long rides in Brooklyn
duration_75_all = merged['duration_mins'].quantile(0.75)
distance_75_all = merged['trip_distance'].quantile(0.75)

# using & instead of | to define long rides to take into account impact of delays and traffic
b_long_rides = brooklyn_cleaned[(brooklyn_cleaned['duration_mins'] >= duration_75_all) & (brooklyn_cleaned['trip_distance'] >= distance_75_all)] # all rides with long durations and distances
b_long_rides_count = b_long_rides.shape[0]
b_long_rides_percentage = (b_long_rides_count / total_brooklyn_rides) * 100
print(f"% of long rides in Brooklyn (by duration and distance): {b_long_rides_percentage:.2f}%")
# Out:
# % of short rides in Brooklyn (by duration or distance): 14.74%
# % of long rides in Brooklyn (by duration and distance): 25.79%

# %%
# comparing % of long rides in Brooklyn to Manhattan
# defining long rides in Manhattan using the same 75th percentile values
m_long_rides = manhattan_cleaned[(manhattan_cleaned['duration_mins'] >= duration_75_all) & (manhattan_cleaned['trip_distance'] >= distance_75_all)] # all rides with long durations and distances
m_long_rides_count = m_long_rides.shape[0]
total_manhattan_rides = manhattan_cleaned.shape[0]
m_long_rides_percentage = (m_long_rides_count / total_manhattan_rides) * 100
print(f"% of long rides in Manhattan (by duration and distance): {m_long_rides_percentage:.2f}%")
# Out:
# % of long rides in Manhattan (by duration and distance): 6.67%

# %% [markdown]
# > Brooklyn having a bigger % of longer rides show that, on average, it's likely to be more spaced out and less "walkable" compared to Manhattan. The smaller % of short rides also reinforces that taxi trips are likely to be longer than Manhattan.

# %%
# Checking for non airport-related rides in Brooklyn
b_is_airport = (brooklyn_overall['PU_service_zone'].str.contains('Airport') | brooklyn_overall['DO_service_zone'].str.contains('Airport'))
non_airport_rides = brooklyn_overall[~b_is_airport]  # number of rides that are not airport-related
print(f"% of non-airport rides in Brooklyn: {non_airport_rides.shape[0]/brooklyn_overall.shape[0] * 100:.2f}%")
# Out:
# % of non-airport rides in Brooklyn: 85.81%

# %% [markdown]
# >Analyzing the rest of the boroughs: Bronx

# %%
# strictly Bronx (PU_Borough and DO_Borough both equal 'Bronx')
bronx = merged[(merged['PU_Borough'] == 'Bronx') & (merged['DO_Borough'] == 'Bronx')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
bronx_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
bronx = bronx[bronx_datetime_cols + [c for c in bronx.columns if c not in bronx_datetime_cols]]
bronx.head()
# Out:
#              PU_datetime         DO_datetime  duration_mins  trip_distance  \
# 3809 2025-05-01 02:53:48 2025-05-01 02:53:58       0.166667           0.02
# 3810 2025-05-01 02:53:48 2025-05-01 02:53:58       0.166667           0.02
# 4388 2025-05-01 04:58:21 2025-05-01 05:08:25      10.066667           4.28
# 6589 2025-05-01 06:56:33 2025-05-01 08:05:18      68.750000           9.20
# 6856 2025-05-01 06:49:55 2025-05-01 07:44:07      54.200000           6.30
#
#      passenger_count             PU_Zone PU_service_zone  \
# 3809             1.0      West Concourse       Boro Zone
# 3810             1.0      West Concourse       Boro Zone
# 4388             1.0         Hunts Point       Boro Zone
# 6589             1.0  Morrisania/Melrose       Boro Zone
# 6856             1.0  Morrisania/Melrose       Boro Zone
#
#                    DO_Zone DO_service_zone  VendorID  RatecodeID  \
# 3809        West Concourse       Boro Zone         2         5.0
# 3810        West Concourse       Boro Zone         2         5.0
# 4388            Mount Hope       Boro Zone         2         1.0
# 6589  Van Nest/Morris Park       Boro Zone         1        99.0
# 6856               Norwood       Boro Zone         1        99.0
#
#       PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 3809           247           247             4        -42.2   -1.0     -0.5
# 3810           247           247             4         42.2    1.0      0.5
# 4388           126           169             1         18.4    1.0      0.5
# 6589           167           242             1         27.5    0.0      0.5
# 6856           167           174             1         28.5    0.0      0.5
#
#       tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 3809         0.0           0.0                   -1.0        -47.95
# 3810         0.0           0.0                    1.0         47.95
# 4388         0.0           0.0                    1.0         20.90
# 6589         0.0           0.0                    0.0         28.00
# 6856         0.0           0.0                    0.0         29.00
#
#       congestion_surcharge  Airport_fee  cbd_congestion_fee PU_Borough  \
# 3809                  -2.5          0.0               -0.75      Bronx
# 3810                   2.5          0.0                0.75      Bronx
# 4388                   0.0          0.0                0.00      Bronx
# 6589                   0.0          0.0                0.00      Bronx
# 6856                   0.0          0.0                0.00      Bronx
#
#      DO_Borough                        vendor_name payment_method  \
# 3809      Bronx                 Curb Mobility, LLC        Dispute
# 3810      Bronx                 Curb Mobility, LLC        Dispute
# 4388      Bronx                 Curb Mobility, LLC    Credit card
# 6589      Bronx  Creative Mobile Technologies, LLC    Credit card
# 6856      Bronx  Creative Mobile Technologies, LLC    Credit card
#
#                  Rate
# 3809  Negotiated fare
# 3810  Negotiated fare
# 4388        Standard
# 6589     Null/Unknown
# 6856     Null/Unknown

# %%
bronx[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count   19315.000000   19315.000000
# mean       16.502069      81.086826
# std        10.145838    2776.613192
# min        -0.550000       0.000000
# 25%        10.583333       1.600000
# 50%        15.100000       3.110000
# 75%        20.666667       5.100000
# max       519.533333  132178.780000

# %%
# let's filter out the extreme outliers in both columns
bronx_cleaned = remove_outliers(bronx)
bronx_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count   17419.000000   17419.000000
# mean       16.286914       3.738788
# std         7.685055       2.255315
# min         2.233333       0.020000
# 25%        10.916667       1.900000
# 50%        15.116667       3.360000
# 75%        20.283333       5.190000
# max        47.166667      10.710000

# %%
# top 10 most frequent ride combinations strictly within Bronx
bronx_cleaned.groupby(['PU_Zone', 'DO_Zone']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(10)
# Out:
#                      PU_Zone                           DO_Zone  count
# 800   Mott Haven/Port Morris                    West Concourse     60
# 782   Mott Haven/Port Morris                     Melrose South     58
# 704            Melrose South            Mott Haven/Port Morris     58
# 803   Mott Haven/Port Morris          Williamsbridge/Olinville     57
# 1167   Soundview/Castle Hill             Soundview/Castle Hill     56
# 784   Mott Haven/Port Morris            Mott Haven/Port Morris     54
# 775   Mott Haven/Port Morris                      East Tremont     54
# 774   Mott Haven/Port Morris  East Concourse/Concourse Village     53
# 785   Mott Haven/Port Morris                        Mount Hope     51
# 742       Morrisania/Melrose                     Melrose South     51

# %%
# numbers seem small
# checking the amount of rides within the same zone for strictly Bronx
br_same_zone_count = bronx[bronx['PU_Zone'] == bronx['DO_Zone']].shape[0]
br_same_zone_percentage = (br_same_zone_count/bronx.shape[0])*100  # percentage of rides within the same zone in Bronx
print(f"% of same zone rides in Bronx: {br_same_zone_percentage:.2f}%")
# Out:
# % of same zone rides in Bronx: 6.60%

# %%
# rides involving Bronx (either PU_Borough or DO_Borough equal 'Bronx')
bronx_overall = merged[(merged['PU_Borough'] == 'Bronx') | (merged['DO_Borough'] == 'Bronx')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
bronx_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
bronx_overall = bronx_overall[bronx_datetime_cols + [c for c in bronx_overall.columns if c not in bronx_datetime_cols]]
bronx_overall.groupby(['PU_Zone', 'DO_Zone']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(10)
# Out:
#                      PU_Zone                              DO_Zone  count
# 4234             JFK Airport           Spuyten Duyvil/Kingsbridge    227
# 4230             JFK Airport  Riverdale/North Riverdale/Fieldston    207
# 4223             JFK Airport               Mott Haven/Port Morris    204
# 4587       LaGuardia Airport           Spuyten Duyvil/Kingsbridge    178
# 4576       LaGuardia Airport               Mott Haven/Port Morris    167
# 4213             JFK Airport     East Concourse/Concourse Village    158
# 5890  Mott Haven/Port Morris               Mott Haven/Port Morris    153
# 4231             JFK Airport         Schuylerville/Edgewater Park    147
# 5791  Mott Haven/Port Morris                 Central Harlem North    146
# 4583       LaGuardia Airport  Riverdale/North Riverdale/Fieldston    139

# %%
# checking the amount of rides in each service_zone for Bronx
bronx_overall['PU_service_zone'].value_counts()  # not much airport-related rides in Bronx
# Out:
# PU_service_zone
# Boro Zone      51986
# Yellow Zone    15533
# Airports        5729
# EWR                1
# Name: count, dtype: int64

# %% [markdown]
# >Analyzing the rest of the boroughs: Staten Island

# %%
# strictly Staten Island (PU_Borough and DO_Borough both equal 'Staten Island')
staten_island = merged[(merged['PU_Borough'] == 'Staten Island') & (merged['DO_Borough'] == 'Staten Island')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
staten_island_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
staten_island = staten_island[staten_island_datetime_cols + [c for c in staten_island.columns if c not in staten_island_datetime_cols]]
staten_island.head()
# Out:
#                PU_datetime         DO_datetime  duration_mins  trip_distance  \
# 161085 2025-05-02 12:32:44 2025-05-02 12:45:14      12.500000           4.51
# 185265 2025-05-02 16:05:37 2025-05-02 16:49:46      44.150000           9.01
# 205941 2025-05-02 18:45:29 2025-05-02 18:52:10       6.683333           1.20
# 258868 2025-05-03 05:19:45 2025-05-03 05:19:52       0.116667           0.00
# 258869 2025-05-03 05:20:56 2025-05-03 05:21:00       0.066667           0.00
#
#        passenger_count                    PU_Zone PU_service_zone  \
# 161085             1.0    Bloomfield/Emerson Hill       Boro Zone
# 185265             1.0  Saint George/New Brighton       Boro Zone
# 205941             1.0                  Stapleton       Boro Zone
# 258868             1.0   South Beach/Dongan Hills       Boro Zone
# 258869             1.0   South Beach/Dongan Hills       Boro Zone
#
#                             DO_Zone DO_service_zone  VendorID  RatecodeID  \
# 161085              Mariners Harbor       Boro Zone         2         1.0
# 185265  Heartland Village/Todt Hill       Boro Zone         2         1.0
# 205941                    Stapleton       Boro Zone         1         1.0
# 258868     South Beach/Dongan Hills       Boro Zone         2         5.0
# 258869     South Beach/Dongan Hills       Boro Zone         2         5.0
#
#         PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 161085            23           156             2         19.8    0.0      0.5
# 185265           206           118             1         47.1    2.5      0.5
# 205941           221           221             2          7.9    2.5      0.5
# 258868           214           214             2         80.0    0.0      0.5
# 258869           214           214             2         82.0    0.0      0.5
#
#         tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 161085         0.0           0.0                    1.0          21.3
# 185265        10.0           0.0                    1.0          61.1
# 205941         0.0           0.0                    1.0          11.9
# 258868         0.0           0.0                    1.0          81.5
# 258869         0.0           0.0                    1.0          83.5
#
#         congestion_surcharge  Airport_fee  cbd_congestion_fee     PU_Borough  \
# 161085                   0.0          0.0                 0.0  Staten Island
# 185265                   0.0          0.0                 0.0  Staten Island
# 205941                   0.0          0.0                 0.0  Staten Island
# 258868                   0.0          0.0                 0.0  Staten Island
# 258869                   0.0          0.0                 0.0  Staten Island
#
#            DO_Borough                        vendor_name payment_method  \
# 161085  Staten Island                 Curb Mobility, LLC           Cash
# 185265  Staten Island                 Curb Mobility, LLC    Credit card
# 205941  Staten Island  Creative Mobile Technologies, LLC           Cash
# 258868  Staten Island                 Curb Mobility, LLC           Cash
# 258869  Staten Island                 Curb Mobility, LLC           Cash
#
#                    Rate
# 161085        Standard
# 185265        Standard
# 205941        Standard
# 258868  Negotiated fare
# 258869  Negotiated fare

# %%
# there's not much trip data of Staten Island
staten_island.shape[0]
# Out:
# 139

# %%
# rides involving Staten Island (either PU_Borough or DO_Borough equal 'Staten Island')
staten_island_overall = merged[(merged['PU_Borough'] == 'Staten Island') | (merged['DO_Borough'] == 'Staten Island')].rename(columns={'tpep_pickup_datetime': 'PU_datetime', 'tpep_dropoff_datetime': 'DO_datetime'})

# reindexing to have the columns in a more readable order
staten_island_datetime_cols = ['PU_datetime', 'DO_datetime', 'duration_mins', 'trip_distance', 'passenger_count', 'PU_Zone', 'PU_service_zone', 'DO_Zone', 'DO_service_zone']
staten_island_overall = staten_island_overall[staten_island_datetime_cols + [c for c in staten_island_overall.columns if c not in staten_island_datetime_cols]]

staten_island_overall.shape[0]  # checking the number of rides involving Staten Island
# Out:
# 1732

# %% [markdown]
# > a good chunk of the trips are inter-borough

# %%
staten_island_overall[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count    1732.000000    1732.000000
# mean       45.600751      64.950525
# std        39.723202    1980.351867
# min        -0.933333       0.000000
# 25%        27.937500      10.630000
# 50%        41.991667      18.150000
# 75%        57.666667      24.772500
# max       978.883333   82433.400000

# %%
# let's filter out the extreme outliers in both columns
staten_island_cleaned = remove_outliers(staten_island)
staten_island_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count     112.000000     112.000000
# mean       11.154911       2.859464
# std         6.803384       1.945837
# min         0.966667       0.040000
# 25%         6.512500       1.330000
# 50%         9.666667       2.210000
# 75%        15.120833       4.105000
# max        36.966667       8.110000

# %%
# comparing to the overall Staten Island rides
staten_island_overall_cleaned = remove_outliers(staten_island_overall)
staten_island_overall_cleaned[['duration_mins', 'trip_distance']].describe()
# Out:
#        duration_mins  trip_distance
# count    1611.000000    1611.000000
# mean       44.503311      17.945034
# std        22.641577       8.282682
# min         3.033333       0.760000
# 25%        29.516667      11.900000
# 50%        42.166667      18.490000
# 75%        57.025000      24.770000
# max       126.566667      35.500000

# %%
# checking the distribution of dropoff boroughs for Staten Island rides
staten_island_overall['DO_Borough'].value_counts()
# Out:
# DO_Borough
# Staten Island    1367
# Brooklyn          264
# Manhattan          78
# Queens             19
# Bronx               3
# Unknown             1
# Name: count, dtype: int64

# %% [markdown]
# > Compared to the rest of the boroughs, it has the shortest in terms of duration and distance within the borough. But when we take a look at the inter-borough trips, it increases a dramatic amount
#
# > Additionally, much of the drop off points are to Staten Island
# * Could be related to more traffic the closer to the center of the city or bridges

# %% [markdown]
# #### **Key Findings:**
# 1. Manhattan has the most ride frequency out of all the 5 boroughs, followed by Queens, Brooklyn, Bronx, Staten Island in that order
#
# 2. Most yellow taxi rides in Manhattan are not hyper-local, but instead cross zones or neighborhoods
#
# 3. Brooklyn & Queens seem to have longer trips than Manhattan, could be geographically more spaced out, whereas Manhattan seems more “walkable”. Therefore, Manhattan's “walkability” reduces the need for taxis for very short, local trips
#
# 4. There’s a high volume of airport type services within Queens due to JFK & LaGuardia being located there, taxis are most likely used for less casual means than that of Manhattan
#
# 5. As a whole, Taxi services seem to be less popular in Bronx, and especially in Staten Island
#
# 6. Potential relationships with the mismatch in duration and distance to traffic, factors such as being closer to the city, or the major bridges

# %% [markdown]
# ---
# **Note:** *Before going into analysis with fares & tips, it's important to note that there may be values that are negative, but they might just be cancelled fares, there should be a duplicate value but in a positive value*
#
# #### **1. Location Segmentation & Tipping Behavior**
#   * Specifically with the specific zones in the top and bottom boroughs
#     * Recall the datetime dataframes of each borough

# %% [markdown]
# ---
# #### **2.Time Segmentation & Tipping Behavior**
# * Let's take a closer look at whether there are datetime trends:
#   * Weekends (people could be going out more)
#   * Maybe there are activities after working hours (events, personal outings)
#   * Time of day: morning, afternoon, night
